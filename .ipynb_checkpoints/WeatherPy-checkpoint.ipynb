# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * Not only is the weather warmer at the Equator (0 Deg. Latitude) as we expected, but you can clearly see that the southern hemisphere is warmer than the northern hemisphere during this season, as we would expect.
# * City cloudiness appears to be reported in bands around 20%, 40%, and 80%, suggesting that it is recorded qualitatively by meteorologists, or that the values are binned.
# * Wind speed does seem to be related to latitude, with lower wind speeds overall around the Equator. This is due to the weak horizontal pressure gradients in this region.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
# lat_lngs = []
cities = []
country_codes = []
# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1])#.city_name
    city_name = city.city_name
    country_code = city.country_code
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city_name)
        country_codes.append(country_code)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 1500

# %%
# Create empty dataframe

city_weather_df = pd.DataFrame()
city_weather_df["City"] = cities
city_weather_df["Country Code"] = country_codes
city_weather_df["City_Number"] = ""
city_weather_df["Lat"] = ""
city_weather_df["Lng"] = ""
city_weather_df["Temp_F"] = ""
city_weather_df["Humidity (%)"] = ""
city_weather_df["Cloudiness (%)"] = ""
city_weather_df["Wind Speed (mph)"] = ""
city_weather_df.head()
# Out:
#           City Country Code City_Number Lat Lng Temp_F Humidity (%)  \
# 0     hargeysa           so
# 1     hermanus           za
# 2   codrington           ag
# 3        amapa           br
# 4  east london           za
#
#   Cloudiness (%) Wind Speed (mph)
# 0
# 1
# 2
# 3
# 4

# %%
len(city_weather_df["City"])
# Out:
# 1500

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"

# %%
# Iterate through the dataframe and make calls to OpenWeather API
# for each city listed in the City column


for index, row in city_weather_df.iterrows():
    city_name = row["City"]
    country_code = row["Country Code"]
    # Assemble url to make requests
    print(f"Processing Index {index}: {city_name}")
    response = requests.get(base_url + "appid=" + api_key + \
                            "&q=" + city_name +"," + country_code + "&units=imperial").json()
    
  #  results = response['results']
    
    try:
        city_weather_df.loc[index, "City_Number"] = response["id"]
        
        city_weather_df.loc[index, "Lat"] = response["coord"]["lat"]
        
        city_weather_df.loc[index, "Lng"] = response["coord"]["lon"]
        
        city_weather_df.loc[index, "Temp_F"] = response["main"]["temp"]
        
        city_weather_df.loc[index, "Humidity (%)"] = response["main"]["humidity"]
        
        city_weather_df.loc[index, "Cloudiness (%)"] = response["clouds"]["all"]
        
        city_weather_df.loc[index, "Wind Speed (mph)"] = response["wind"]["speed"]
       
    except (KeyError, IndexError):
        print("City not found. Skipping...")
    
print("""
-----------------------
Data Retrieval Complete
-----------------------""")
# Out:
# Processing Index 0: hargeysa
# made it this far
# Processing Index 1: hermanus
# made it this far
# Processing Index 2: codrington
# City not found. Skipping...
# Processing Index 3: amapa
# made it this far
# Processing Index 4: east london
# made it this far
# Processing Index 5: port alfred
# made it this far
# Processing Index 6: tura
# made it this far
# Processing Index 7: nikolskoye
# made it this far
# Processing Index 8: vaini
# made it this far
# Processing Index 9: busselton
# made it this far
# Processing Index 10: lazaro cardenas
# made it this far
# Processing Index 11: ilulissat
# made it this far
# Processing Index 12: nanortalik
# made it this far
# Processing Index 13: busselton
# made it this far
# Processing Index 14: klaksvik
# made it this far
# Processing Index 15: kaitangata
# made it this far
# Processing Index 16: itapecerica
# made it this far
# Processing Index 17: nantucket
# made it this far
# Processing Index 18: evensk
# made it this far
# Processing Index 19: hermanus
# made it this far
# Processing Index 20: ruatoria
# City not found. Skipping...
# Processing Index 21: henties bay
# made it this far
# Processing Index 22: atuona
# made it this far
# Processing Index 23: ribeira grande
# made it this far
# Processing Index 24: polyarnyy
# made it this far
# Processing Index 25: bethanien
# made it this far
# Processing Index 26: berlevag
# made it this far
# Processing Index 27: punta arenas
# made it this far
# Processing Index 28: busselton
# made it this far
# Processing Index 29: chuy
# made it this far
# Processing Index 30: hinton
# made it this far
# Processing Index 31: rikitea
# made it this far
# Processing Index 32: ribeira brava
# City not found. Skipping...
# Processing Index 33: delijan
# made it this far
# Processing Index 34: punta arenas
# made it this far
# Processing Index 35: hobart
# made it this far
# Processing Index 36: pevek
# made it this far
# Processing Index 37: svetlyy
# City not found. Skipping...
# Processing Index 38: codrington
# City not found. Skipping...
# Processing Index 39: hermanus
# made it this far
# Processing Index 40: khorramshahr
# made it this far
# Processing Index 41: mount gambier
# made it this far
# Processing Index 42: cidreira
# made it this far
# Processing Index 43: vaini
# made it this far
# Processing Index 44: cody
# made it this far
# Processing Index 45: calama
# made it this far
# Processing Index 46: matagami
# made it this far
# Processing Index 47: bathsheba
# made it this far
# Processing Index 48: cape town
# made it this far
# Processing Index 49: naifaru
# made it this far
# Processing Index 50: barentsburg
# City not found. Skipping...
# Processing Index 51: avarua
# made it this far
# Processing Index 52: meiktila
# made it this far
# Processing Index 53: alvaraes
# made it this far
# Processing Index 54: port elizabeth
# made it this far
# Processing Index 55: nantucket
# made it this far
# Processing Index 56: hithadhoo
# made it this far
# Processing Index 57: belushya guba
# City not found. Skipping...
# Processing Index 58: high level
# made it this far
# Processing Index 59: belushya guba
# City not found. Skipping...
# Processing Index 60: hobart
# made it this far
# Processing Index 61: mombetsu
# made it this far
# Processing Index 62: albany
# made it this far
# Processing Index 63: barrow
# made it this far
# Processing Index 64: severo-kurilsk
# made it this far
# Processing Index 65: coolum beach
# made it this far
# Processing Index 66: ngunguru
# made it this far
# Processing Index 67: nantucket
# made it this far
# Processing Index 68: padang
# made it this far
# Processing Index 69: east london
# made it this far
# Processing Index 70: tsihombe
# City not found. Skipping...
# Processing Index 71: ponta delgada
# made it this far
# Processing Index 72: ushuaia
# made it this far
# Processing Index 73: sabang
# made it this far
# Processing Index 74: issum
# made it this far
# Processing Index 75: lata
# City not found. Skipping...
# Processing Index 76: punta arenas
# made it this far
# Processing Index 77: monrovia
# made it this far
# Processing Index 78: sassandra
# made it this far
# Processing Index 79: tiksi
# made it this far
# Processing Index 80: umzimvubu
# City not found. Skipping...
# Processing Index 81: zhigansk
# made it this far
# Processing Index 82: katsuura
# made it this far
# Processing Index 83: constitucion
# made it this far
# Processing Index 84: sola
# made it this far
# Processing Index 85: klaksvik
# made it this far
# Processing Index 86: talnakh
# made it this far
# Processing Index 87: bambous virieux
# made it this far
# Processing Index 88: upernavik
# made it this far
# Processing Index 89: punta arenas
# made it this far
# Processing Index 90: hermanus
# made it this far
# Processing Index 91: ouadda
# made it this far
# Processing Index 92: lebu
# made it this far
# Processing Index 93: esil
# made it this far
# Processing Index 94: iqaluit
# made it this far
# Processing Index 95: new norfolk
# made it this far
# Processing Index 96: lompoc
# made it this far
# Processing Index 97: barrow
# made it this far
# Processing Index 98: puerto leguizamo
# made it this far
# Processing Index 99: albany
# made it this far
# Processing Index 100: taolanaro
# City not found. Skipping...
# Processing Index 101: santa cruz de tenerife
# made it this far
# Processing Index 102: rikitea
# made it this far
# Processing Index 103: bethel
# made it this far
# Processing Index 104: aneho
# made it this far
# Processing Index 105: adet
# made it this far
# Processing Index 106: port antonio
# made it this far
# Processing Index 107: albany
# made it this far
# Processing Index 108: castro
# made it this far
# Processing Index 109: baft
# made it this far
# Processing Index 110: khatanga
# made it this far
# Processing Index 111: carnarvon
# made it this far
# Processing Index 112: karratha
# made it this far
# Processing Index 113: shingu
# made it this far
# Processing Index 114: avarua
# made it this far
# Processing Index 115: haibowan
# City not found. Skipping...
# Processing Index 116: komsomolskiy
# made it this far
# Processing Index 117: wahpeton
# made it this far
# Processing Index 118: punta arenas
# made it this far
# Processing Index 119: colquechaca
# made it this far
# Processing Index 120: julio de castilhos
# made it this far
# Processing Index 121: punta arenas
# made it this far
# Processing Index 122: puerto ayora
# made it this far
# Processing Index 123: ribeira grande
# made it this far
# Processing Index 124: bluff
# made it this far
# Processing Index 125: jamestown
# made it this far
# Processing Index 126: auki
# made it this far
# Processing Index 127: noumea
# made it this far
# Processing Index 128: albany
# made it this far
# Processing Index 129: mataura
# City not found. Skipping...
# Processing Index 130: busselton
# made it this far
# Processing Index 131: castro
# made it this far
# Processing Index 132: gubkinskiy
# made it this far
# Processing Index 133: cape town
# made it this far
# Processing Index 134: bluff
# made it this far
# Processing Index 135: tabuk
# made it this far
# Processing Index 136: bethel
# made it this far
# Processing Index 137: barentsburg
# City not found. Skipping...
# Processing Index 138: bolungarvik
# City not found. Skipping...
# Processing Index 139: erenhot
# made it this far
# Processing Index 140: grand gaube
# made it this far
# Processing Index 141: khani
# City not found. Skipping...
# Processing Index 142: airai
# City not found. Skipping...
# Processing Index 143: yellowknife
# made it this far
# Processing Index 144: hithadhoo
# made it this far
# Processing Index 145: sao paulo de olivenca
# made it this far
# Processing Index 146: hilo
# made it this far
# Processing Index 147: mizdah
# made it this far
# Processing Index 148: yellowknife
# made it this far
# Processing Index 149: hilo
# made it this far
# Processing Index 150: port blair
# made it this far
# Processing Index 151: ilulissat
# made it this far
# Processing Index 152: bredy
# made it this far
# Processing Index 153: tuggurt
# City not found. Skipping...
# Processing Index 154: yellowknife
# made it this far
# Processing Index 155: albany
# made it this far
# Processing Index 156: port elizabeth
# made it this far
# Processing Index 157: barentsburg
# City not found. Skipping...
# Processing Index 158: saint-philippe
# made it this far
# Processing Index 159: katsuura
# made it this far
# Processing Index 160: tasiilaq
# made it this far
# Processing Index 161: kisangani
# made it this far
# Processing Index 162: lorengau
# made it this far
# Processing Index 163: karpogory
# made it this far
# Processing Index 164: oktyabrskiy
# made it this far
# Processing Index 165: cape town
# made it this far
# Processing Index 166: yellowknife
# made it this far
# Processing Index 167: rikitea
# made it this far
# Processing Index 168: mataura
# City not found. Skipping...
# Processing Index 169: busselton
# made it this far
# Processing Index 170: rikitea
# made it this far
# Processing Index 171: sibu
# made it this far
# Processing Index 172: new norfolk
# made it this far
# Processing Index 173: lompoc
# made it this far
# Processing Index 174: tabiauea
# City not found. Skipping...
# Processing Index 175: new norfolk
# made it this far
# Processing Index 176: skiros
# City not found. Skipping...
# Processing Index 177: saquarema
# made it this far
# Processing Index 178: hermanus
# made it this far
# Processing Index 179: saint george
# made it this far
# Processing Index 180: kuching
# made it this far
# Processing Index 181: busselton
# made it this far
# Processing Index 182: imbituva
# made it this far
# Processing Index 183: campbell river
# made it this far
# Processing Index 184: kieta
# made it this far
# Processing Index 185: touros
# made it this far
# Processing Index 186: asau
# City not found. Skipping...
# Processing Index 187: sangar
# made it this far
# Processing Index 188: punta arenas
# made it this far
# Processing Index 189: taraz
# made it this far
# Processing Index 190: ushuaia
# made it this far
# Processing Index 191: kieta
# made it this far
# Processing Index 192: new norfolk
# made it this far
# Processing Index 193: barrow
# made it this far
# Processing Index 194: castro
# made it this far
# Processing Index 195: castro
# made it this far
# Processing Index 196: punta arenas
# made it this far
# Processing Index 197: the valley
# made it this far
# Processing Index 198: jamestown
# made it this far
# Processing Index 199: atuona
# made it this far
# Processing Index 200: port alfred
# made it this far
# Processing Index 201: osinovo
# made it this far
# Processing Index 202: kahului
# made it this far
# Processing Index 203: rikitea
# made it this far
# Processing Index 204: cherskiy
# made it this far
# Processing Index 205: pimentel
# made it this far
# Processing Index 206: bredasdorp
# made it this far
# Processing Index 207: guerrero negro
# made it this far
# Processing Index 208: yarke pole
# made it this far
# Processing Index 209: rikitea
# made it this far
# Processing Index 210: manzanillo
# made it this far
# Processing Index 211: thompson
# made it this far
# Processing Index 212: rikitea
# made it this far
# Processing Index 213: puerto ayora
# made it this far
# Processing Index 214: bandarbeyla
# made it this far
# Processing Index 215: bambous virieux
# made it this far
# Processing Index 216: rikitea
# made it this far
# Processing Index 217: ushuaia
# made it this far
# Processing Index 218: chokurdakh
# made it this far
# Processing Index 219: nanortalik
# made it this far
# Processing Index 220: alofi
# made it this far
# Processing Index 221: yellowknife
# made it this far
# Processing Index 222: butaritari
# made it this far
# Processing Index 223: pringsewu
# made it this far
# Processing Index 224: svetlaya
# made it this far
# Processing Index 225: saldanha
# made it this far
# Processing Index 226: kapaa
# made it this far
# Processing Index 227: sao filipe
# made it this far
# Processing Index 228: malanje
# made it this far
# Processing Index 229: new norfolk
# made it this far
# Processing Index 230: bredasdorp
# made it this far
# Processing Index 231: bethel
# made it this far
# Processing Index 232: east london
# made it this far
# Processing Index 233: bluff
# made it this far
# Processing Index 234: rikitea
# made it this far
# Processing Index 235: brazzaville
# made it this far
# Processing Index 236: ola
# made it this far
# Processing Index 237: lebu
# made it this far
# Processing Index 238: avera
# City not found. Skipping...
# Processing Index 239: iqaluit
# made it this far
# Processing Index 240: itarema
# made it this far
# Processing Index 241: bluff
# made it this far
# Processing Index 242: sisimiut
# made it this far
# Processing Index 243: olinda
# made it this far
# Processing Index 244: boguchany
# made it this far
# Processing Index 245: odweyne
# City not found. Skipping...
# Processing Index 246: bay roberts
# made it this far
# Processing Index 247: hay river
# made it this far
# Processing Index 248: cape town
# made it this far
# Processing Index 249: port hardy
# made it this far
# Processing Index 250: rungata
# City not found. Skipping...
# Processing Index 251: lar
# made it this far
# Processing Index 252: lebu
# made it this far
# Processing Index 253: faanui
# made it this far
# Processing Index 254: jamestown
# made it this far
# Processing Index 255: sur
# made it this far
# Processing Index 256: chapais
# made it this far
# Processing Index 257: airai
# City not found. Skipping...
# Processing Index 258: mys shmidta
# City not found. Skipping...
# Processing Index 259: maningrida
# made it this far
# Processing Index 260: dikson
# made it this far
# Processing Index 261: mahebourg
# made it this far
# Processing Index 262: busselton
# made it this far
# Processing Index 263: rikitea
# made it this far
# Processing Index 264: bargal
# City not found. Skipping...
# Processing Index 265: ribeira grande
# made it this far
# Processing Index 266: kirovskiy
# made it this far
# Processing Index 267: mataura
# City not found. Skipping...
# Processing Index 268: pevek
# made it this far
# Processing Index 269: lebu
# made it this far
# Processing Index 270: mys shmidta
# City not found. Skipping...
# Processing Index 271: rikitea
# made it this far
# Processing Index 272: cianjur
# made it this far
# Processing Index 273: jamestown
# made it this far
# Processing Index 274: alice springs
# made it this far
# Processing Index 275: yulara
# made it this far
# Processing Index 276: punta arenas
# made it this far
# Processing Index 277: yellowknife
# made it this far
# Processing Index 278: cape town
# made it this far
# Processing Index 279: severo-kurilsk
# made it this far
# Processing Index 280: busselton
# made it this far
# Processing Index 281: rikitea
# made it this far
# Processing Index 282: cape town
# made it this far
# Processing Index 283: vilyuysk
# made it this far
# Processing Index 284: rikitea
# made it this far
# Processing Index 285: punta arenas
# made it this far
# Processing Index 286: gallup
# made it this far
# Processing Index 287: lagoa
# made it this far
# Processing Index 288: lagoa
# made it this far
# Processing Index 289: avarua
# made it this far
# Processing Index 290: rikitea
# made it this far
# Processing Index 291: mataura
# City not found. Skipping...
# Processing Index 292: khatanga
# made it this far
# Processing Index 293: hasaki
# made it this far
# Processing Index 294: mataura
# City not found. Skipping...
# Processing Index 295: ushuaia
# made it this far
# Processing Index 296: kapaa
# made it this far
# Processing Index 297: ushuaia
# made it this far
# Processing Index 298: tagusao
# made it this far
# Processing Index 299: mataura
# City not found. Skipping...
# Processing Index 300: vestmannaeyjar
# made it this far
# Processing Index 301: saskylakh
# made it this far
# Processing Index 302: cherskiy
# made it this far
# Processing Index 303: ketchikan
# made it this far
# Processing Index 304: hilo
# made it this far
# Processing Index 305: ardakan
# made it this far
# Processing Index 306: sur
# made it this far
# Processing Index 307: fairbanks
# made it this far
# Processing Index 308: nome
# made it this far
# Processing Index 309: mataura
# City not found. Skipping...
# Processing Index 310: fort-shevchenko
# made it this far
# Processing Index 311: saleaula
# City not found. Skipping...
# Processing Index 312: masuguru
# made it this far
# Processing Index 313: castro
# made it this far
# Processing Index 314: hasaki
# made it this far
# Processing Index 315: ancud
# made it this far
# Processing Index 316: ylivieska
# made it this far
# Processing Index 317: mataura
# City not found. Skipping...
# Processing Index 318: cidreira
# made it this far
# Processing Index 319: esso
# made it this far
# Processing Index 320: punta arenas
# made it this far
# Processing Index 321: raudeberg
# made it this far
# Processing Index 322: kapaa
# made it this far
# Processing Index 323: vestmannaeyjar
# made it this far
# Processing Index 324: port alfred
# made it this far
# Processing Index 325: kharhial
# made it this far
# Processing Index 326: port lincoln
# made it this far
# Processing Index 327: hermanus
# made it this far
# Processing Index 328: rovaniemi
# made it this far
# Processing Index 329: wheatley
# made it this far
# Processing Index 330: iqaluit
# made it this far
# Processing Index 331: east london
# made it this far
# Processing Index 332: leh
# made it this far
# Processing Index 333: isangel
# made it this far
# Processing Index 334: castro
# made it this far
# Processing Index 335: nizhneyansk
# City not found. Skipping...
# Processing Index 336: ushuaia
# made it this far
# Processing Index 337: cherskiy
# made it this far
# Processing Index 338: yeniseysk
# made it this far
# Processing Index 339: angra
# City not found. Skipping...
# Processing Index 340: ponta delgada
# made it this far
# Processing Index 341: viru
# made it this far
# Processing Index 342: ewa beach
# made it this far
# Processing Index 343: cidreira
# made it this far
# Processing Index 344: kodiak
# made it this far
# Processing Index 345: mataura
# City not found. Skipping...
# Processing Index 346: carnarvon
# made it this far
# Processing Index 347: saint george
# made it this far
# Processing Index 348: louisbourg
# City not found. Skipping...
# Processing Index 349: cape town
# made it this far
# Processing Index 350: port elizabeth
# made it this far
# Processing Index 351: tiksi
# made it this far
# Processing Index 352: veraval
# made it this far
# Processing Index 353: chapais
# made it this far
# Processing Index 354: chupei
# City not found. Skipping...
# Processing Index 355: bobcaygeon
# made it this far
# Processing Index 356: torbay
# made it this far
# Processing Index 357: suntar
# made it this far
# Processing Index 358: gobabis
# made it this far
# Processing Index 359: arraial do cabo
# made it this far
# Processing Index 360: taolanaro
# City not found. Skipping...
# Processing Index 361: pochutla
# made it this far
# Processing Index 362: lasa
# City not found. Skipping...
# Processing Index 363: rikitea
# made it this far
# Processing Index 364: upernavik
# made it this far
# Processing Index 365: sentyabrskiy
# City not found. Skipping...
# Processing Index 366: souillac
# made it this far
# Processing Index 367: stargard szczecinski
# made it this far
# Processing Index 368: rikitea
# made it this far
# Processing Index 369: taolanaro
# City not found. Skipping...
# Processing Index 370: ushuaia
# made it this far
# Processing Index 371: razdolinsk
# made it this far
# Processing Index 372: lavrentiya
# made it this far
# Processing Index 373: sentyabrskiy
# City not found. Skipping...
# Processing Index 374: tsihombe
# City not found. Skipping...
# Processing Index 375: puerto ayora
# made it this far
# Processing Index 376: rikitea
# made it this far
# Processing Index 377: charters towers
# made it this far
# Processing Index 378: mataura
# City not found. Skipping...
# Processing Index 379: aklavik
# made it this far
# Processing Index 380: port alfred
# made it this far
# Processing Index 381: clyde river
# made it this far
# Processing Index 382: kapaa
# made it this far
# Processing Index 383: san patricio
# made it this far
# Processing Index 384: saint george
# made it this far
# Processing Index 385: san cristobal
# made it this far
# Processing Index 386: cururupu
# made it this far
# Processing Index 387: saint george
# made it this far
# Processing Index 388: esperance
# made it this far
# Processing Index 389: bengkulu
# City not found. Skipping...
# Processing Index 390: amderma
# City not found. Skipping...
# Processing Index 391: ingham
# made it this far
# Processing Index 392: rio gallegos
# made it this far
# Processing Index 393: cabcab
# made it this far
# Processing Index 394: new norfolk
# made it this far
# Processing Index 395: paamiut
# made it this far
# Processing Index 396: busselton
# made it this far
# Processing Index 397: bubaque
# made it this far
# Processing Index 398: uvat
# made it this far
# Processing Index 399: khatanga
# made it this far
# Processing Index 400: nome
# made it this far
# Processing Index 401: vaini
# made it this far
# Processing Index 402: tasiilaq
# made it this far
# Processing Index 403: lagoa
# made it this far
# Processing Index 404: illoqqortoormiut
# City not found. Skipping...
# Processing Index 405: upernavik
# made it this far
# Processing Index 406: fonte boa
# made it this far
# Processing Index 407: saskylakh
# made it this far
# Processing Index 408: ancud
# made it this far
# Processing Index 409: ushuaia
# made it this far
# Processing Index 410: lebu
# made it this far
# Processing Index 411: eyl
# made it this far
# Processing Index 412: mangan
# made it this far
# Processing Index 413: atuona
# made it this far
# Processing Index 414: albany
# made it this far
# Processing Index 415: orumiyeh
# made it this far
# Processing Index 416: bredasdorp
# made it this far
# Processing Index 417: tiksi
# made it this far
# Processing Index 418: berlevag
# made it this far
# Processing Index 419: barentsburg
# City not found. Skipping...
# Processing Index 420: bati
# made it this far
# Processing Index 421: rikitea
# made it this far
# Processing Index 422: iqaluit
# made it this far
# Processing Index 423: ribeira grande
# made it this far
# Processing Index 424: ushuaia
# made it this far
# Processing Index 425: bethel
# made it this far
# Processing Index 426: nikolskoye
# made it this far
# Processing Index 427: bondo
# made it this far
# Processing Index 428: vaini
# made it this far
# Processing Index 429: jubayl
# City not found. Skipping...
# Processing Index 430: bull savanna
# made it this far
# Processing Index 431: ambon
# made it this far
# Processing Index 432: punta arenas
# made it this far
# Processing Index 433: attawapiskat
# City not found. Skipping...
# Processing Index 434: saleaula
# City not found. Skipping...
# Processing Index 435: bethel
# made it this far
# Processing Index 436: burnie
# made it this far
# Processing Index 437: manati
# City not found. Skipping...
# Processing Index 438: busselton
# made it this far
# Processing Index 439: rikitea
# made it this far
# Processing Index 440: atar
# made it this far
# Processing Index 441: butte
# made it this far
# Processing Index 442: iqaluit
# made it this far
# Processing Index 443: barentsburg
# City not found. Skipping...
# Processing Index 444: punta arenas
# made it this far
# Processing Index 445: dikson
# made it this far
# Processing Index 446: atuona
# made it this far
# Processing Index 447: hilo
# made it this far
# Processing Index 448: barrow
# made it this far
# Processing Index 449: taolanaro
# City not found. Skipping...
# Processing Index 450: ushuaia
# made it this far
# Processing Index 451: florianopolis
# made it this far
# Processing Index 452: salalah
# made it this far
# Processing Index 453: taolanaro
# City not found. Skipping...
# Processing Index 454: kaoma
# made it this far
# Processing Index 455: padang
# made it this far
# Processing Index 456: huanren
# made it this far
# Processing Index 457: castro
# made it this far
# Processing Index 458: ca mau
# made it this far
# Processing Index 459: albany
# made it this far
# Processing Index 460: qaanaaq
# made it this far
# Processing Index 461: tuktoyaktuk
# made it this far
# Processing Index 462: qaanaaq
# made it this far
# Processing Index 463: vaini
# made it this far
# Processing Index 464: torbay
# made it this far
# Processing Index 465: puerto ayora
# made it this far
# Processing Index 466: hilo
# made it this far
# Processing Index 467: barentsburg
# City not found. Skipping...
# Processing Index 468: komsomolskiy
# made it this far
# Processing Index 469: barrow
# made it this far
# Processing Index 470: lebu
# made it this far
# Processing Index 471: ushuaia
# made it this far
# Processing Index 472: cabo san lucas
# made it this far
# Processing Index 473: nizhneyansk
# City not found. Skipping...
# Processing Index 474: hobart
# made it this far
# Processing Index 475: coihaique
# made it this far
# Processing Index 476: tooele
# made it this far
# Processing Index 477: imphal
# made it this far
# Processing Index 478: tsabong
# made it this far
# Processing Index 479: yangambi
# made it this far
# Processing Index 480: rikitea
# made it this far
# Processing Index 481: carnarvon
# made it this far
# Processing Index 482: cape town
# made it this far
# Processing Index 483: busselton
# made it this far
# Processing Index 484: punta arenas
# made it this far
# Processing Index 485: saleaula
# City not found. Skipping...
# Processing Index 486: mahajanga
# made it this far
# Processing Index 487: jamestown
# made it this far
# Processing Index 488: belushya guba
# City not found. Skipping...
# Processing Index 489: mataura
# City not found. Skipping...
# Processing Index 490: cartagena del chaira
# made it this far
# Processing Index 491: chuy
# made it this far
# Processing Index 492: punta arenas
# made it this far
# Processing Index 493: ferrol
# made it this far
# Processing Index 494: lagoa
# made it this far
# Processing Index 495: fortuna
# made it this far
# Processing Index 496: buala
# made it this far
# Processing Index 497: punta arenas
# made it this far
# Processing Index 498: katherine
# made it this far
# Processing Index 499: sur
# made it this far
# Processing Index 500: kapaa
# made it this far
# Processing Index 501: moerai
# made it this far
# Processing Index 502: bulgan
# made it this far
# Processing Index 503: mumford
# made it this far
# Processing Index 504: ushuaia
# made it this far
# Processing Index 505: faya
# City not found. Skipping...
# Processing Index 506: okahandja
# made it this far
# Processing Index 507: berlevag
# made it this far
# Processing Index 508: busselton
# made it this far
# Processing Index 509: sibolga
# made it this far
# Processing Index 510: punta arenas
# made it this far
# Processing Index 511: hobart
# made it this far
# Processing Index 512: ushuaia
# made it this far
# Processing Index 513: hasaki
# made it this far
# Processing Index 514: rikitea
# made it this far
# Processing Index 515: smithers
# made it this far
# Processing Index 516: constitucion
# made it this far
# Processing Index 517: hilo
# made it this far
# Processing Index 518: hermanus
# made it this far
# Processing Index 519: mar del plata
# made it this far
# Processing Index 520: nikolskoye
# made it this far
# Processing Index 521: yumen
# made it this far
# Processing Index 522: mataura
# City not found. Skipping...
# Processing Index 523: bluff
# made it this far
# Processing Index 524: dikson
# made it this far
# Processing Index 525: bluff
# made it this far
# Processing Index 526: oulainen
# made it this far
# Processing Index 527: pangnirtung
# made it this far
# Processing Index 528: vila velha
# made it this far
# Processing Index 529: saint-philippe
# made it this far
# Processing Index 530: bethel
# made it this far
# Processing Index 531: urucui
# made it this far
# Processing Index 532: dwarka
# made it this far
# Processing Index 533: puerto ayora
# made it this far
# Processing Index 534: mataura
# City not found. Skipping...
# Processing Index 535: atherton
# made it this far
# Processing Index 536: busselton
# made it this far
# Processing Index 537: punta arenas
# made it this far
# Processing Index 538: new norfolk
# made it this far
# Processing Index 539: hasaki
# made it this far
# Processing Index 540: ola
# made it this far
# Processing Index 541: grand-lahou
# made it this far
# Processing Index 542: kudahuvadhoo
# made it this far
# Processing Index 543: vaini
# made it this far
# Processing Index 544: chokurdakh
# made it this far
# Processing Index 545: ilulissat
# made it this far
# Processing Index 546: palabuhanratu
# City not found. Skipping...
# Processing Index 547: bluff
# made it this far
# Processing Index 548: bredasdorp
# made it this far
# Processing Index 549: attawapiskat
# City not found. Skipping...
# Processing Index 550: gizo
# made it this far
# Processing Index 551: clyde river
# made it this far
# Processing Index 552: ushuaia
# made it this far
# Processing Index 553: komsomolets
# made it this far
# Processing Index 554: grand river south east
# City not found. Skipping...
# Processing Index 555: punta arenas
# made it this far
# Processing Index 556: vila velha
# made it this far
# Processing Index 557: port shepstone
# made it this far
# Processing Index 558: isangel
# made it this far
# Processing Index 559: bolshaya murta
# City not found. Skipping...
# Processing Index 560: vaini
# made it this far
# Processing Index 561: tura
# made it this far
# Processing Index 562: port alfred
# made it this far
# Processing Index 563: bobonong
# City not found. Skipping...
# Processing Index 564: methoni
# made it this far
# Processing Index 565: caravelas
# made it this far
# Processing Index 566: abaza
# made it this far
# Processing Index 567: clyde river
# made it this far
# Processing Index 568: tiksi
# made it this far
# Processing Index 569: punta arenas
# made it this far
# Processing Index 570: nelson bay
# made it this far
# Processing Index 571: belushya guba
# City not found. Skipping...
# Processing Index 572: palmerston
# made it this far
# Processing Index 573: bambous virieux
# made it this far
# Processing Index 574: rikitea
# made it this far
# Processing Index 575: coihaique
# made it this far
# Processing Index 576: pundaguitan
# made it this far
# Processing Index 577: hermanus
# made it this far
# Processing Index 578: ushuaia
# made it this far
# Processing Index 579: sao jose da coroa grande
# made it this far
# Processing Index 580: jaisalmer
# made it this far
# Processing Index 581: talnakh
# made it this far
# Processing Index 582: bluff
# made it this far
# Processing Index 583: kroderen
# City not found. Skipping...
# Processing Index 584: bluff
# made it this far
# Processing Index 585: meulaboh
# made it this far
# Processing Index 586: samalaeulu
# City not found. Skipping...
# Processing Index 587: grand gaube
# made it this far
# Processing Index 588: louisbourg
# City not found. Skipping...
# Processing Index 589: san patricio
# made it this far
# Processing Index 590: anloga
# made it this far
# Processing Index 591: harper
# made it this far
# Processing Index 592: kununurra
# made it this far
# Processing Index 593: georgetown
# made it this far
# Processing Index 594: lichinga
# made it this far
# Processing Index 595: grand river south east
# City not found. Skipping...
# Processing Index 596: rikitea
# made it this far
# Processing Index 597: roberto payan
# City not found. Skipping...
# Processing Index 598: punta arenas
# made it this far
# Processing Index 599: nouadhibou
# made it this far
# Processing Index 600: portland
# made it this far
# Processing Index 601: fortuna
# made it this far
# Processing Index 602: vaini
# made it this far
# Processing Index 603: edd
# made it this far
# Processing Index 604: snezhnogorsk
# made it this far
# Processing Index 605: uthal
# made it this far
# Processing Index 606: beyneu
# made it this far
# Processing Index 607: albany
# made it this far
# Processing Index 608: narsaq
# made it this far
# Processing Index 609: sioux lookout
# made it this far
# Processing Index 610: atuona
# made it this far
# Processing Index 611: lompoc
# made it this far
# Processing Index 612: airai
# City not found. Skipping...
# Processing Index 613: cherskiy
# made it this far
# Processing Index 614: arraial do cabo
# made it this far
# Processing Index 615: cape town
# made it this far
# Processing Index 616: khandyga
# made it this far
# Processing Index 617: mys shmidta
# City not found. Skipping...
# Processing Index 618: bredasdorp
# made it this far
# Processing Index 619: lagoa
# made it this far
# Processing Index 620: bluff
# made it this far
# Processing Index 621: hilo
# made it this far
# Processing Index 622: kapoeta
# City not found. Skipping...
# Processing Index 623: angoche
# made it this far
# Processing Index 624: maraa
# made it this far
# Processing Index 625: villazon
# City not found. Skipping...
# Processing Index 626: egvekinot
# made it this far
# Processing Index 627: meulaboh
# made it this far
# Processing Index 628: qaanaaq
# made it this far
# Processing Index 629: candido mota
# made it this far
# Processing Index 630: rikitea
# made it this far
# Processing Index 631: taolanaro
# City not found. Skipping...
# Processing Index 632: bathsheba
# made it this far
# Processing Index 633: grand river south east
# City not found. Skipping...
# Processing Index 634: vaini
# made it this far
# Processing Index 635: ushuaia
# made it this far
# Processing Index 636: tuktoyaktuk
# made it this far
# Processing Index 637: taoudenni
# made it this far
# Processing Index 638: juegang
# made it this far
# Processing Index 639: chokurdakh
# made it this far
# Processing Index 640: alindao
# made it this far
# Processing Index 641: nouadhibou
# made it this far
# Processing Index 642: durango
# made it this far
# Processing Index 643: arraial do cabo
# made it this far
# Processing Index 644: mount pleasant
# made it this far
# Processing Index 645: xai-xai
# made it this far
# Processing Index 646: isangel
# made it this far
# Processing Index 647: port elizabeth
# made it this far
# Processing Index 648: sembakung
# made it this far
# Processing Index 649: rocha
# made it this far
# Processing Index 650: new norfolk
# made it this far
# Processing Index 651: vaini
# made it this far
# Processing Index 652: yuci
# made it this far
# Processing Index 653: butaritari
# made it this far
# Processing Index 654: hithadhoo
# made it this far
# Processing Index 655: necochea
# made it this far
# Processing Index 656: lagoa
# made it this far
# Processing Index 657: kunzelsau
# made it this far
# Processing Index 658: rikitea
# made it this far
# Processing Index 659: mouila
# made it this far
# Processing Index 660: hermanus
# made it this far
# Processing Index 661: saint-pierre
# made it this far
# Processing Index 662: yaan
# City not found. Skipping...
# Processing Index 663: hermanus
# made it this far
# Processing Index 664: oktyabrskoye
# made it this far
# Processing Index 665: saldanha
# made it this far
# Processing Index 666: hermanus
# made it this far
# Processing Index 667: belushya guba
# City not found. Skipping...
# Processing Index 668: kamenskoye
# City not found. Skipping...
# Processing Index 669: cuxhaven
# made it this far
# Processing Index 670: mataura
# City not found. Skipping...
# Processing Index 671: airai
# City not found. Skipping...
# Processing Index 672: kyra
# made it this far
# Processing Index 673: bassila
# made it this far
# Processing Index 674: laguna
# City not found. Skipping...
# Processing Index 675: bredasdorp
# made it this far
# Processing Index 676: mys shmidta
# City not found. Skipping...
# Processing Index 677: kapaa
# made it this far
# Processing Index 678: vaini
# made it this far
# Processing Index 679: qaanaaq
# made it this far
# Processing Index 680: avarua
# made it this far
# Processing Index 681: hobyo
# made it this far
# Processing Index 682: thompson
# made it this far
# Processing Index 683: atuona
# made it this far
# Processing Index 684: albany
# made it this far
# Processing Index 685: margate
# made it this far
# Processing Index 686: flin flon
# made it this far
# Processing Index 687: ponta do sol
# made it this far
# Processing Index 688: kangaatsiaq
# made it this far
# Processing Index 689: meulaboh
# made it this far
# Processing Index 690: tura
# made it this far
# Processing Index 691: belmonte
# made it this far
# Processing Index 692: qaanaaq
# made it this far
# Processing Index 693: antofagasta
# made it this far
# Processing Index 694: payo
# City not found. Skipping...
# Processing Index 695: port elizabeth
# made it this far
# Processing Index 696: vila do maio
# made it this far
# Processing Index 697: stryn
# made it this far
# Processing Index 698: bengkulu
# City not found. Skipping...
# Processing Index 699: sisophon
# made it this far
# Processing Index 700: ushuaia
# made it this far
# Processing Index 701: arraial do cabo
# made it this far
# Processing Index 702: marsa matruh
# made it this far
# Processing Index 703: bluff
# made it this far
# Processing Index 704: barrow
# made it this far
# Processing Index 705: kavieng
# made it this far
# Processing Index 706: portland
# made it this far
# Processing Index 707: qaanaaq
# made it this far
# Processing Index 708: kiunga
# made it this far
# Processing Index 709: ushuaia
# made it this far
# Processing Index 710: ushuaia
# made it this far
# Processing Index 711: gedo
# made it this far
# Processing Index 712: samusu
# City not found. Skipping...
# Processing Index 713: norman
# made it this far
# Processing Index 714: kaspiyskiy
# made it this far
# Processing Index 715: ponta do sol
# made it this far
# Processing Index 716: hermanus
# made it this far
# Processing Index 717: tarudant
# City not found. Skipping...
# Processing Index 718: saskylakh
# made it this far
# Processing Index 719: ribeira grande
# made it this far
# Processing Index 720: port alfred
# made it this far
# Processing Index 721: punta arenas
# made it this far
# Processing Index 722: koratla
# made it this far
# Processing Index 723: husavik
# made it this far
# Processing Index 724: hakui
# made it this far
# Processing Index 725: punta arenas
# made it this far
# Processing Index 726: puerto ayora
# made it this far
# Processing Index 727: poya
# made it this far
# Processing Index 728: rikitea
# made it this far
# Processing Index 729: les cayes
# made it this far
# Processing Index 730: bambous virieux
# made it this far
# Processing Index 731: ilulissat
# made it this far
# Processing Index 732: atambua
# made it this far
# Processing Index 733: holland
# made it this far
# Processing Index 734: severo-kurilsk
# made it this far
# Processing Index 735: kodiak
# made it this far
# Processing Index 736: east london
# made it this far
# Processing Index 737: castro
# made it this far
# Processing Index 738: hermanus
# made it this far
# Processing Index 739: olafsvik
# City not found. Skipping...
# Processing Index 740: ushuaia
# made it this far
# Processing Index 741: cape town
# made it this far
# Processing Index 742: nizhneyansk
# City not found. Skipping...
# Processing Index 743: georgetown
# made it this far
# Processing Index 744: lethem
# made it this far
# Processing Index 745: hobart
# made it this far
# Processing Index 746: mahebourg
# made it this far
# Processing Index 747: punta arenas
# made it this far
# Processing Index 748: atuona
# made it this far
# Processing Index 749: kaeo
# made it this far
# Processing Index 750: cidreira
# made it this far
# Processing Index 751: urumqi
# City not found. Skipping...
# Processing Index 752: east london
# made it this far
# Processing Index 753: shaunavon
# made it this far
# Processing Index 754: severo-kurilsk
# made it this far
# Processing Index 755: norman wells
# made it this far
# Processing Index 756: sur
# made it this far
# Processing Index 757: two rivers
# made it this far
# Processing Index 758: busselton
# made it this far
# Processing Index 759: qaanaaq
# made it this far
# Processing Index 760: san patricio
# made it this far
# Processing Index 761: busselton
# made it this far
# Processing Index 762: punta arenas
# made it this far
# Processing Index 763: sao filipe
# made it this far
# Processing Index 764: khatanga
# made it this far
# Processing Index 765: sitio novo do tocantins
# City not found. Skipping...
# Processing Index 766: sentyabrskiy
# City not found. Skipping...
# Processing Index 767: georgetown
# made it this far
# Processing Index 768: dikson
# made it this far
# Processing Index 769: taolanaro
# City not found. Skipping...
# Processing Index 770: hermanus
# made it this far
# Processing Index 771: la ronge
# made it this far
# Processing Index 772: arraial do cabo
# made it this far
# Processing Index 773: nizhneyansk
# City not found. Skipping...
# Processing Index 774: eenhana
# made it this far
# Processing Index 775: cherskiy
# made it this far
# Processing Index 776: los llanos de aridane
# made it this far
# Processing Index 777: nikolskoye
# made it this far
# Processing Index 778: ushuaia
# made it this far
# Processing Index 779: taolanaro
# City not found. Skipping...
# Processing Index 780: grand gaube
# made it this far
# Processing Index 781: cairns
# made it this far
# Processing Index 782: bilma
# made it this far
# Processing Index 783: souillac
# made it this far
# Processing Index 784: nabire
# made it this far
# Processing Index 785: faya
# City not found. Skipping...
# Processing Index 786: palabuhanratu
# City not found. Skipping...
# Processing Index 787: yellowknife
# made it this far
# Processing Index 788: nemuro
# made it this far
# Processing Index 789: kapaa
# made it this far
# Processing Index 790: butaritari
# made it this far
# Processing Index 791: georgetown
# made it this far
# Processing Index 792: saint-philippe
# made it this far
# Processing Index 793: barrow
# made it this far
# Processing Index 794: saint anthony
# City not found. Skipping...
# Processing Index 795: bluff
# made it this far
# Processing Index 796: makakilo city
# made it this far
# Processing Index 797: new norfolk
# made it this far
# Processing Index 798: hilo
# made it this far
# Processing Index 799: dibaya
# City not found. Skipping...
# Processing Index 800: port lincoln
# made it this far
# Processing Index 801: araouane
# made it this far
# Processing Index 802: karkaralinsk
# City not found. Skipping...
# Processing Index 803: vaini
# made it this far
# Processing Index 804: hasaki
# made it this far
# Processing Index 805: bonthe
# made it this far
# Processing Index 806: busselton
# made it this far
# Processing Index 807: rock sound
# made it this far
# Processing Index 808: hanzhong
# made it this far
# Processing Index 809: kapaa
# made it this far
# Processing Index 810: yellowknife
# made it this far
# Processing Index 811: coatepec harinas
# made it this far
# Processing Index 812: rikitea
# made it this far
# Processing Index 813: necochea
# made it this far
# Processing Index 814: yellowknife
# made it this far
# Processing Index 815: vallenar
# made it this far
# Processing Index 816: obluche
# City not found. Skipping...
# Processing Index 817: thompson
# made it this far
# Processing Index 818: ancud
# made it this far
# Processing Index 819: amarante do maranhao
# made it this far
# Processing Index 820: sindou
# made it this far
# Processing Index 821: abalak
# made it this far
# Processing Index 822: gimli
# made it this far
# Processing Index 823: orissaare
# made it this far
# Processing Index 824: kapaa
# made it this far
# Processing Index 825: jamestown
# made it this far
# Processing Index 826: norman wells
# made it this far
# Processing Index 827: lolua
# City not found. Skipping...
# Processing Index 828: cape town
# made it this far
# Processing Index 829: novoagansk
# made it this far
# Processing Index 830: mataura
# City not found. Skipping...
# Processing Index 831: ushuaia
# made it this far
# Processing Index 832: cape town
# made it this far
# Processing Index 833: anchorage
# made it this far
# Processing Index 834: falealupo
# City not found. Skipping...
# Processing Index 835: codrington
# City not found. Skipping...
# Processing Index 836: jamestown
# made it this far
# Processing Index 837: belushya guba
# City not found. Skipping...
# Processing Index 838: beyneu
# made it this far
# Processing Index 839: busselton
# made it this far
# Processing Index 840: hermanus
# made it this far
# Processing Index 841: hambantota
# made it this far
# Processing Index 842: punta arenas
# made it this far
# Processing Index 843: longyearbyen
# made it this far
# Processing Index 844: casablanca
# made it this far
# Processing Index 845: busselton
# made it this far
# Processing Index 846: bhubaneswar
# made it this far
# Processing Index 847: punta arenas
# made it this far
# Processing Index 848: saint-philippe
# made it this far
# Processing Index 849: hermanus
# made it this far
# Processing Index 850: mataura
# City not found. Skipping...
# Processing Index 851: goderich
# City not found. Skipping...
# Processing Index 852: jamestown
# made it this far
# Processing Index 853: asau
# City not found. Skipping...
# Processing Index 854: kasangulu
# made it this far
# Processing Index 855: mazara del vallo
# made it this far
# Processing Index 856: geraldton
# made it this far
# Processing Index 857: georgetown
# made it this far
# Processing Index 858: butaritari
# made it this far
# Processing Index 859: gigmoto
# made it this far
# Processing Index 860: ushuaia
# made it this far
# Processing Index 861: kracheh
# City not found. Skipping...
# Processing Index 862: cape town
# made it this far
# Processing Index 863: bukama
# made it this far
# Processing Index 864: upernavik
# made it this far
# Processing Index 865: henties bay
# made it this far
# Processing Index 866: mataura
# City not found. Skipping...
# Processing Index 867: new norfolk
# made it this far
# Processing Index 868: khatanga
# made it this far
# Processing Index 869: upernavik
# made it this far
# Processing Index 870: rikitea
# made it this far
# Processing Index 871: pisco
# made it this far
# Processing Index 872: minsk
# made it this far
# Processing Index 873: aflu
# City not found. Skipping...
# Processing Index 874: sassandra
# made it this far
# Processing Index 875: port elizabeth
# made it this far
# Processing Index 876: ushuaia
# made it this far
# Processing Index 877: puerto ayora
# made it this far
# Processing Index 878: punta arenas
# made it this far
# Processing Index 879: waddan
# made it this far
# Processing Index 880: mvangue
# made it this far
# Processing Index 881: ilulissat
# made it this far
# Processing Index 882: yellowknife
# made it this far
# Processing Index 883: alakurtti
# made it this far
# Processing Index 884: punta arenas
# made it this far
# Processing Index 885: kodiak
# made it this far
# Processing Index 886: bathsheba
# made it this far
# Processing Index 887: puerto ayora
# made it this far
# Processing Index 888: yagodnoye
# made it this far
# Processing Index 889: thompson
# made it this far
# Processing Index 890: airai
# City not found. Skipping...
# Processing Index 891: taolanaro
# City not found. Skipping...
# Processing Index 892: vaini
# made it this far
# Processing Index 893: avera
# City not found. Skipping...
# Processing Index 894: jaru
# made it this far
# Processing Index 895: mataura
# City not found. Skipping...
# Processing Index 896: port elizabeth
# made it this far
# Processing Index 897: cockburn town
# made it this far
# Processing Index 898: puerto escondido
# made it this far
# Processing Index 899: taolanaro
# City not found. Skipping...
# Processing Index 900: nguru
# made it this far
# Processing Index 901: arraial do cabo
# made it this far
# Processing Index 902: ambodifototra
# City not found. Skipping...
# Processing Index 903: belushya guba
# City not found. Skipping...
# Processing Index 904: newport
# made it this far
# Processing Index 905: cidreira
# made it this far
# Processing Index 906: ossora
# made it this far
# Processing Index 907: sentyabrskiy
# City not found. Skipping...
# Processing Index 908: ushuaia
# made it this far
# Processing Index 909: walvis bay
# made it this far
# Processing Index 910: cape town
# made it this far
# Processing Index 911: lebu
# made it this far
# Processing Index 912: jamestown
# made it this far
# Processing Index 913: saleaula
# City not found. Skipping...
# Processing Index 914: butaritari
# made it this far
# Processing Index 915: asau
# City not found. Skipping...
# Processing Index 916: kruisfontein
# made it this far
# Processing Index 917: mataura
# City not found. Skipping...
# Processing Index 918: vaini
# made it this far
# Processing Index 919: albany
# made it this far
# Processing Index 920: norman wells
# made it this far
# Processing Index 921: ushuaia
# made it this far
# Processing Index 922: marsa matruh
# made it this far
# Processing Index 923: albany
# made it this far
# Processing Index 924: nanortalik
# made it this far
# Processing Index 925: bintulu
# made it this far
# Processing Index 926: zhangjiakou
# made it this far
# Processing Index 927: lebu
# made it this far
# Processing Index 928: yellowknife
# made it this far
# Processing Index 929: saint-philippe
# made it this far
# Processing Index 930: tuktoyaktuk
# made it this far
# Processing Index 931: rikitea
# made it this far
# Processing Index 932: butaritari
# made it this far
# Processing Index 933: belushya guba
# City not found. Skipping...
# Processing Index 934: albany
# made it this far
# Processing Index 935: belushya guba
# City not found. Skipping...
# Processing Index 936: atuona
# made it this far
# Processing Index 937: kodiak
# made it this far
# Processing Index 938: belaya gora
# made it this far
# Processing Index 939: port alfred
# made it this far
# Processing Index 940: mataura
# City not found. Skipping...
# Processing Index 941: chuy
# made it this far
# Processing Index 942: zamora
# made it this far
# Processing Index 943: teshie
# made it this far
# Processing Index 944: kitimat
# made it this far
# Processing Index 945: candawaga
# City not found. Skipping...
# Processing Index 946: busselton
# made it this far
# Processing Index 947: hilo
# made it this far
# Processing Index 948: rikitea
# made it this far
# Processing Index 949: joaima
# made it this far
# Processing Index 950: puerto ayora
# made it this far
# Processing Index 951: tsihombe
# City not found. Skipping...
# Processing Index 952: rikitea
# made it this far
# Processing Index 953: lavrentiya
# made it this far
# Processing Index 954: saint anthony
# City not found. Skipping...
# Processing Index 955: liverpool
# made it this far
# Processing Index 956: klaksvik
# made it this far
# Processing Index 957: canberra
# made it this far
# Processing Index 958: barentsburg
# City not found. Skipping...
# Processing Index 959: torbay
# made it this far
# Processing Index 960: mataura
# ...
# made it this far
# Processing Index 1188: atuona
# made it this far
# Processing Index 1189: novyy urengoy
# made it this far
# Processing Index 1190: humberto de campos
# made it this far
# Processing Index 1191: nikolskoye
# made it this far
# Processing Index 1192: rio gallegos
# made it this far
# Processing Index 1193: isangel
# made it this far
# Processing Index 1194: arraial do cabo
# made it this far
# Processing Index 1195: jamestown
# made it this far
# Processing Index 1196: mar del plata
# made it this far
# Processing Index 1197: tuktoyaktuk
# made it this far
# Processing Index 1198: ushuaia
# made it this far
# Processing Index 1199: saleaula
# City not found. Skipping...
# Processing Index 1200: mataura
# City not found. Skipping...
# Processing Index 1201: hermanus
# made it this far
# Processing Index 1202: atuona
# made it this far
# Processing Index 1203: ushuaia
# made it this far
# Processing Index 1204: porto novo
# made it this far
# Processing Index 1205: olaine
# made it this far
# Processing Index 1206: mataura
# City not found. Skipping...
# Processing Index 1207: tigil
# made it this far
# Processing Index 1208: butaritari
# made it this far
# Processing Index 1209: kavieng
# made it this far
# Processing Index 1210: flinders
# made it this far
# Processing Index 1211: vestmannaeyjar
# made it this far
# Processing Index 1212: mataura
# City not found. Skipping...
# Processing Index 1213: bluff
# made it this far
# Processing Index 1214: concepcion del oro
# made it this far
# Processing Index 1215: port hawkesbury
# made it this far
# Processing Index 1216: muros
# made it this far
# Processing Index 1217: sao paulo de olivenca
# made it this far
# Processing Index 1218: lebu
# made it this far
# Processing Index 1219: severo-kurilsk
# made it this far
# Processing Index 1220: thompson
# made it this far
# Processing Index 1221: butaritari
# made it this far
# Processing Index 1222: tasiilaq
# made it this far
# Processing Index 1223: saint-philippe
# made it this far
# Processing Index 1224: faanui
# made it this far
# Processing Index 1225: chancay
# made it this far
# Processing Index 1226: port elizabeth
# made it this far
# Processing Index 1227: albany
# made it this far
# Processing Index 1228: adamovka
# made it this far
# Processing Index 1229: rikitea
# made it this far
# Processing Index 1230: busselton
# made it this far
# Processing Index 1231: ushuaia
# made it this far
# Processing Index 1232: itoman
# made it this far
# Processing Index 1233: vaini
# made it this far
# Processing Index 1234: padang
# made it this far
# Processing Index 1235: albany
# made it this far
# Processing Index 1236: mataura
# City not found. Skipping...
# Processing Index 1237: henties bay
# made it this far
# Processing Index 1238: bluff
# made it this far
# Processing Index 1239: kapaa
# made it this far
# Processing Index 1240: mataura
# City not found. Skipping...
# Processing Index 1241: mount gambier
# made it this far
# Processing Index 1242: jamestown
# made it this far
# Processing Index 1243: yellowknife
# made it this far
# Processing Index 1244: port macquarie
# made it this far
# Processing Index 1245: merke
# made it this far
# Processing Index 1246: ayer itam
# City not found. Skipping...
# Processing Index 1247: dikson
# made it this far
# Processing Index 1248: ushuaia
# made it this far
# Processing Index 1249: bima
# made it this far
# Processing Index 1250: mataura
# City not found. Skipping...
# Processing Index 1251: hermanus
# made it this far
# Processing Index 1252: hobart
# made it this far
# Processing Index 1253: elizabeth city
# made it this far
# Processing Index 1254: hithadhoo
# made it this far
# Processing Index 1255: atuona
# made it this far
# Processing Index 1256: plettenberg bay
# made it this far
# Processing Index 1257: thomastown
# made it this far
# Processing Index 1258: taolanaro
# City not found. Skipping...
# Processing Index 1259: iqaluit
# made it this far
# Processing Index 1260: mys shmidta
# City not found. Skipping...
# Processing Index 1261: zhigalovo
# made it this far
# Processing Index 1262: kloulklubed
# made it this far
# Processing Index 1263: vrede
# made it this far
# Processing Index 1264: cape town
# made it this far
# Processing Index 1265: isangel
# made it this far
# Processing Index 1266: ahipara
# made it this far
# Processing Index 1267: stranda
# made it this far
# Processing Index 1268: katsuura
# made it this far
# Processing Index 1269: umzimvubu
# City not found. Skipping...
# Processing Index 1270: yarada
# made it this far
# Processing Index 1271: elat
# City not found. Skipping...
# Processing Index 1272: ayagoz
# made it this far
# Processing Index 1273: krasnoselkup
# City not found. Skipping...
# Processing Index 1274: rikitea
# made it this far
# Processing Index 1275: leh
# made it this far
# Processing Index 1276: clyde river
# made it this far
# Processing Index 1277: kodiak
# made it this far
# Processing Index 1278: suntar
# made it this far
# Processing Index 1279: yellowknife
# made it this far
# Processing Index 1280: mahebourg
# made it this far
# Processing Index 1281: labytnangi
# made it this far
# Processing Index 1282: busselton
# made it this far
# Processing Index 1283: barrow
# made it this far
# Processing Index 1284: punta arenas
# made it this far
# Processing Index 1285: ushuaia
# made it this far
# Processing Index 1286: mahebourg
# made it this far
# Processing Index 1287: hobart
# made it this far
# Processing Index 1288: yangambi
# made it this far
# Processing Index 1289: butaritari
# made it this far
# Processing Index 1290: kavieng
# made it this far
# Processing Index 1291: iqaluit
# made it this far
# Processing Index 1292: butaritari
# made it this far
# Processing Index 1293: cerro azul
# made it this far
# Processing Index 1294: hollins
# made it this far
# Processing Index 1295: punta arenas
# made it this far
# Processing Index 1296: mys shmidta
# City not found. Skipping...
# Processing Index 1297: bluff
# made it this far
# Processing Index 1298: bambous virieux
# made it this far
# Processing Index 1299: kuito
# made it this far
# Processing Index 1300: severo-kurilsk
# made it this far
# Processing Index 1301: puerto ayora
# made it this far
# Processing Index 1302: coahuayana
# made it this far
# Processing Index 1303: illoqqortoormiut
# City not found. Skipping...
# Processing Index 1304: norman wells
# made it this far
# Processing Index 1305: cape town
# made it this far
# Processing Index 1306: vinukonda
# made it this far
# Processing Index 1307: santa rosa
# made it this far
# Processing Index 1308: joaima
# made it this far
# Processing Index 1309: cherskiy
# made it this far
# Processing Index 1310: lagoa
# made it this far
# Processing Index 1311: bubaque
# made it this far
# Processing Index 1312: klyuchi
# made it this far
# Processing Index 1313: lata
# City not found. Skipping...
# Processing Index 1314: mrirt
# City not found. Skipping...
# Processing Index 1315: ilulissat
# made it this far
# Processing Index 1316: codrington
# City not found. Skipping...
# Processing Index 1317: santa fe
# made it this far
# Processing Index 1318: cape town
# made it this far
# Processing Index 1319: puerto princesa
# made it this far
# Processing Index 1320: tsihombe
# City not found. Skipping...
# Processing Index 1321: ewa beach
# made it this far
# Processing Index 1322: vysokaya gora
# City not found. Skipping...
# Processing Index 1323: hobart
# made it this far
# Processing Index 1324: cape town
# made it this far
# Processing Index 1325: hilo
# made it this far
# Processing Index 1326: ohara
# made it this far
# Processing Index 1327: tsihombe
# City not found. Skipping...
# Processing Index 1328: serebryansk
# made it this far
# Processing Index 1329: barrow
# made it this far
# Processing Index 1330: butaritari
# made it this far
# Processing Index 1331: north bend
# made it this far
# Processing Index 1332: luganville
# made it this far
# Processing Index 1333: atuona
# made it this far
# Processing Index 1334: lebu
# made it this far
# Processing Index 1335: port hedland
# made it this far
# Processing Index 1336: busselton
# made it this far
# Processing Index 1337: airai
# City not found. Skipping...
# Processing Index 1338: chumikan
# made it this far
# Processing Index 1339: saint-augustin
# made it this far
# Processing Index 1340: salalah
# made it this far
# Processing Index 1341: rikitea
# made it this far
# Processing Index 1342: talnakh
# made it this far
# Processing Index 1343: jamestown
# made it this far
# Processing Index 1344: saint-pierre
# made it this far
# Processing Index 1345: taolanaro
# City not found. Skipping...
# Processing Index 1346: ingham
# made it this far
# Processing Index 1347: mataura
# City not found. Skipping...
# Processing Index 1348: mataura
# City not found. Skipping...
# Processing Index 1349: provideniya
# made it this far
# Processing Index 1350: lavrentiya
# made it this far
# Processing Index 1351: kodiak
# made it this far
# Processing Index 1352: taolanaro
# City not found. Skipping...
# Processing Index 1353: albany
# made it this far
# Processing Index 1354: albany
# made it this far
# Processing Index 1355: punta arenas
# made it this far
# Processing Index 1356: yellowknife
# made it this far
# Processing Index 1357: faya
# City not found. Skipping...
# Processing Index 1358: busselton
# made it this far
# Processing Index 1359: busselton
# made it this far
# Processing Index 1360: butaritari
# made it this far
# Processing Index 1361: luau
# made it this far
# Processing Index 1362: avarua
# made it this far
# Processing Index 1363: ancud
# made it this far
# Processing Index 1364: tabou
# made it this far
# Processing Index 1365: tasiilaq
# made it this far
# Processing Index 1366: itarema
# made it this far
# Processing Index 1367: ponta do sol
# made it this far
# Processing Index 1368: bluff
# made it this far
# Processing Index 1369: puerto ayora
# made it this far
# Processing Index 1370: pontianak
# made it this far
# Processing Index 1371: pisco
# made it this far
# Processing Index 1372: leua
# made it this far
# Processing Index 1373: kavieng
# made it this far
# Processing Index 1374: deputatskiy
# made it this far
# Processing Index 1375: cape town
# made it this far
# Processing Index 1376: coquimbo
# made it this far
# Processing Index 1377: kapaa
# made it this far
# Processing Index 1378: yellowknife
# made it this far
# Processing Index 1379: huarmey
# made it this far
# Processing Index 1380: torbay
# made it this far
# Processing Index 1381: rikitea
# made it this far
# Processing Index 1382: bandar-e anzali
# made it this far
# Processing Index 1383: mataura
# City not found. Skipping...
# Processing Index 1384: olafsvik
# City not found. Skipping...
# Processing Index 1385: kushmurun
# City not found. Skipping...
# Processing Index 1386: zhireken
# made it this far
# Processing Index 1387: upernavik
# made it this far
# Processing Index 1388: broken hill
# made it this far
# Processing Index 1389: rikitea
# made it this far
# Processing Index 1390: isabela
# City not found. Skipping...
# Processing Index 1391: dolores
# made it this far
# Processing Index 1392: cape town
# made it this far
# Processing Index 1393: alvand
# made it this far
# Processing Index 1394: ushuaia
# made it this far
# Processing Index 1395: fort saint john
# City not found. Skipping...
# Processing Index 1396: puerto ayora
# made it this far
# Processing Index 1397: banda aceh
# made it this far
# Processing Index 1398: ushuaia
# made it this far
# Processing Index 1399: dikson
# made it this far
# Processing Index 1400: bayshore gardens
# made it this far
# Processing Index 1401: ponta do sol
# made it this far
# Processing Index 1402: cape town
# made it this far
# Processing Index 1403: severo-yeniseyskiy
# made it this far
# Processing Index 1404: kushiro
# made it this far
# Processing Index 1405: san jose
# made it this far
# Processing Index 1406: zhigansk
# made it this far
# Processing Index 1407: mount isa
# made it this far
# Processing Index 1408: tuktoyaktuk
# made it this far
# Processing Index 1409: rikitea
# made it this far
# Processing Index 1410: muravlenko
# made it this far
# Processing Index 1411: kapaa
# made it this far
# Processing Index 1412: albany
# made it this far
# Processing Index 1413: ushuaia
# made it this far
# Processing Index 1414: port blair
# made it this far
# Processing Index 1415: camacha
# made it this far
# Processing Index 1416: bengkulu
# City not found. Skipping...
# Processing Index 1417: ushuaia
# made it this far
# Processing Index 1418: rawson
# made it this far
# Processing Index 1419: hovd
# made it this far
# Processing Index 1420: dikson
# made it this far
# Processing Index 1421: vaini
# made it this far
# Processing Index 1422: coquimbo
# made it this far
# Processing Index 1423: bubaque
# made it this far
# Processing Index 1424: rikitea
# made it this far
# Processing Index 1425: prince albert
# made it this far
# Processing Index 1426: chokurdakh
# made it this far
# Processing Index 1427: tuktoyaktuk
# made it this far
# Processing Index 1428: rikitea
# made it this far
# Processing Index 1429: bengkulu
# City not found. Skipping...
# Processing Index 1430: rikitea
# made it this far
# Processing Index 1431: rikitea
# made it this far
# Processing Index 1432: port hedland
# made it this far
# Processing Index 1433: ballina
# made it this far
# Processing Index 1434: vydrino
# made it this far
# Processing Index 1435: illoqqortoormiut
# City not found. Skipping...
# Processing Index 1436: avarua
# made it this far
# Processing Index 1437: bluff
# made it this far
# Processing Index 1438: springdale
# made it this far
# Processing Index 1439: horta
# made it this far
# Processing Index 1440: tasiilaq
# made it this far
# Processing Index 1441: rumonge
# made it this far
# Processing Index 1442: mataura
# City not found. Skipping...
# Processing Index 1443: tiarei
# made it this far
# Processing Index 1444: kapaa
# made it this far
# Processing Index 1445: namatanai
# made it this far
# Processing Index 1446: cherskiy
# made it this far
# Processing Index 1447: quatre cocos
# made it this far
# Processing Index 1448: ilulissat
# made it this far
# Processing Index 1449: kachikau
# City not found. Skipping...
# Processing Index 1450: vaini
# made it this far
# Processing Index 1451: simpang
# made it this far
# Processing Index 1452: dikson
# made it this far
# Processing Index 1453: paris
# made it this far
# Processing Index 1454: mersing
# made it this far
# Processing Index 1455: lorengau
# made it this far
# Processing Index 1456: fevralsk
# City not found. Skipping...
# Processing Index 1457: barentsburg
# City not found. Skipping...
# Processing Index 1458: nikolskoye
# made it this far
# Processing Index 1459: norman wells
# made it this far
# Processing Index 1460: bambous virieux
# made it this far
# Processing Index 1461: mount isa
# made it this far
# Processing Index 1462: castro
# made it this far
# Processing Index 1463: haifa
# made it this far
# Processing Index 1464: albany
# made it this far
# Processing Index 1465: hermanus
# made it this far
# Processing Index 1466: nhulunbuy
# made it this far
# Processing Index 1467: rikitea
# made it this far
# Processing Index 1468: mataura
# City not found. Skipping...
# Processing Index 1469: albany
# made it this far
# Processing Index 1470: rio grande
# made it this far
# Processing Index 1471: butaritari
# made it this far
# Processing Index 1472: barrow
# made it this far
# Processing Index 1473: rikitea
# made it this far
# Processing Index 1474: arraial do cabo
# made it this far
# Processing Index 1475: sorland
# made it this far
# Processing Index 1476: pangai
# made it this far
# Processing Index 1477: puerto ayora
# made it this far
# Processing Index 1478: saint-philippe
# made it this far
# Processing Index 1479: okuchi
# made it this far
# Processing Index 1480: camacha
# made it this far
# Processing Index 1481: vaini
# made it this far
# Processing Index 1482: upernavik
# made it this far
# Processing Index 1483: rikitea
# made it this far
# Processing Index 1484: karakendzha
# City not found. Skipping...
# Processing Index 1485: busselton
# made it this far
# Processing Index 1486: rikitea
# made it this far
# Processing Index 1487: fairbanks
# made it this far
# Processing Index 1488: palmer
# made it this far
# Processing Index 1489: rikitea
# made it this far
# Processing Index 1490: acajutla
# made it this far
# Processing Index 1491: saskylakh
# made it this far
# Processing Index 1492: portland
# made it this far
# Processing Index 1493: butaritari
# made it this far
# Processing Index 1494: leningradskiy
# made it this far
# Processing Index 1495: hobart
# made it this far
# Processing Index 1496: ponta do sol
# made it this far
# Processing Index 1497: lompoc
# made it this far
# Processing Index 1498: hithadhoo
# made it this far
# Processing Index 1499: taolanaro
# City not found. Skipping...
#
# -----------------------
# Data Retrieval Complete
# -----------------------

# %%
city_weather_df.head()
# Out:
#           City Country Code City_Number    Lat    Lng Temp_F Humidity (%)  \
# 0     hargeysa           so       57289   9.56  44.06  76.49           38
# 1     hermanus           za     3366880 -34.42  19.24  66.34           79
# 2   codrington           ag                NaN
# 3        amapa           br     3401225  -1.83 -56.23  93.95           52
# 4  east london           za     1006984 -33.02  27.91   60.8           93
#
#   Cloudiness (%) Wind Speed (mph)
# 0             36             6.96
# 1             20             8.99
# 2
# 3             20             4.05
# 4             40             3.36

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_weather_df.count()
# Out:
# City                1500
# Country Code        1500
# City_Number         1500
# Lat                 1500
# Lng                 1500
# Temp_F              1500
# Humidity (%)        1500
# Cloudiness (%)      1500
# Wind Speed (mph)    1500
# dtype: int64

# %%
city_weather_df.dtypes
# Out:
# City                object
# Country Code        object
# City_Number         object
# Lat                 object
# Lng                 object
# Temp_F              object
# Humidity (%)        object
# Cloudiness (%)      object
# Wind Speed (mph)    object
# dtype: object

# %%
# Convert data types to numeric where appropriate

city_weather_df["Lat"] = pd.to_numeric(city_weather_df["Lat"])
city_weather_df["Lng"] = pd.to_numeric(city_weather_df["Lng"])
city_weather_df["Temp_F"] = pd.to_numeric(city_weather_df["Temp_F"])
city_weather_df["Humidity (%)"] = pd.to_numeric(city_weather_df["Humidity (%)"])
city_weather_df["Cloudiness (%)"] = pd.to_numeric(city_weather_df["Cloudiness (%)"])
city_weather_df["Wind Speed (mph)"] = pd.to_numeric(city_weather_df["Wind Speed (mph)"])
city_weather_df.dtypes
# Out:
# City                 object
# Country Code         object
# City_Number          object
# Lat                 float64
# Lng                 float64
# Temp_F              float64
# Humidity (%)        float64
# Cloudiness (%)      float64
# Wind Speed (mph)    float64
# dtype: object

# %%
# Export to .csv file

city_weather_df.to_csv(output_data_file, sep = ",")

# %%
# Bring it back in

weather_py_df = pd.read_csv(output_data_file)

weather_py_df.head()
# Out:
#    Unnamed: 0         City Country Code  City_Number    Lat    Lng  Temp_F  \
# 0           0     hargeysa           so      57289.0   9.56  44.06   76.49
# 1           1     hermanus           za    3366880.0 -34.42  19.24   66.34
# 2           2   codrington           ag          NaN    NaN    NaN     NaN
# 3           3        amapa           br    3401225.0  -1.83 -56.23   93.95
# 4           4  east london           za    1006984.0 -33.02  27.91   60.80
#
#    Humidity (%)  Cloudiness (%)  Wind Speed (mph)
# 0          38.0            36.0              6.96
# 1          79.0            20.0              8.99
# 2           NaN             NaN               NaN
# 3          52.0            20.0              4.05
# 4          93.0            40.0              3.36

# %%
weather_py_df.dtypes
# Out:
# Unnamed: 0            int64
# City                 object
# Country Code         object
# City_Number         float64
# Lat                 float64
# Lng                 float64
# Temp_F              float64
# Humidity (%)        float64
# Cloudiness (%)      float64
# Wind Speed (mph)    float64
# dtype: object

# %%
# Need to drop all rows with NAs

weather_py_df = weather_py_df.dropna(how="any")
weather_py_df.count()
# Out:
# Unnamed: 0          1295
# City                1295
# Country Code        1295
# City_Number         1295
# Lat                 1295
# Lng                 1295
# Temp_F              1295
# Humidity (%)        1295
# Cloudiness (%)      1295
# Wind Speed (mph)    1295
# dtype: int64

# %%
weather_py_df.head(10)
# Out:
#     Unnamed: 0             City Country Code  City_Number    Lat     Lng  \
# 0            0         hargeysa           so      57289.0   9.56   44.06
# 1            1         hermanus           za    3366880.0 -34.42   19.24
# 3            3            amapa           br    3401225.0  -1.83  -56.23
# 4            4      east london           za    1006984.0 -33.02   27.91
# 5            5      port alfred           za     964432.0 -33.59   26.89
# 6            6             tura           ru    2014833.0  64.27  100.22
# 7            7       nikolskoye           ru     546105.0  59.70   30.79
# 8            8            vaini           to    4032243.0 -21.20 -175.20
# 9            9        busselton           au    2075265.0 -33.64  115.35
# 10          10  lazaro cardenas           mx    3996234.0  28.39 -105.62
#
#     Temp_F  Humidity (%)  Cloudiness (%)  Wind Speed (mph)
# 0    76.49          38.0            36.0              6.96
# 1    66.34          79.0            20.0              8.99
# 3    93.95          52.0            20.0              4.05
# 4    60.80          93.0            40.0              3.36
# 5    64.00          84.0            48.0              5.99
# 6    23.75          74.0            88.0              2.48
# 7    35.51          55.0             0.0              4.47
# 8    75.20          83.0            20.0              8.05
# 9    58.24          44.0             0.0             22.28
# 10   75.00          16.0            32.0              8.99

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Data used for analysis was saved on 4/02/2019

# x_axis = np.arange(-90, 90, 10)

plt.scatter(weather_py_df["Lat"], weather_py_df["Temp_F"], alpha = 0.2)

plt.ylabel("City Temperature (Fahrenheit)")
plt.xlabel("Latitude")
plt.title("City Temperatures by Latitude on April 2, 2019")
plt.show()

plt.savefig("output_data/temp_lat.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_py_df["Lat"], weather_py_df["Humidity (%)"], alpha = 0.2)

plt.ylabel("City Humidity (%)")
plt.xlabel("Latitude")
plt.title("City Humidity by Latitude on April 2, 2019")
plt.show()
plt.savefig("output_data/hum_lat.png")
# All pretty high humidity, possibly because large cities tend to be
# near large bodies of water

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_py_df["Lat"], weather_py_df["Cloudiness (%)"], alpha = 0.2)

plt.ylabel("City Cloud Cover (%)")
plt.xlabel("Latitude")
plt.title("City Cloud Cover by Latitude on April 2, 2019")
plt.show()
plt.savefig("output_data/cloud_lat.png")
# Note the distinct bands around multiples of 10 for the y axis
# This suggests that the % humidity was reported qualitatively

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_py_df["Lat"], weather_py_df["Wind Speed (mph)"], alpha = 0.2)

plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.title("City Wind Speed by Latitude on April 2, 2019")
plt.show()
plt.savefig("output_data/wind_lat.png")
